# %%
pip install numpy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("data.csv")
df
# Out:
#    Value Sample
# 0   12.5     S1
# 1   15.1     S2
# 2   13.2     S3
# 3   10.8     S4
# 4   14.4     S5

# %%
df["Value"].mean()
# Out:
# np.float64(13.2)

# %%
df["Value"].std()
# Out:
# np.float64(1.6807736313971608)

# %%
df.plot(kind='bar', x='Sample', y='Value')
# Out:
# <Axes: xlabel='Sample'>
